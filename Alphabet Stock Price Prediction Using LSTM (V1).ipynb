# %% [markdown]
# # Predicting Stock Prices Using Recurrent Neural Networks

# %% [markdown]
# ## Importing Packages

# %%
#Load libraries
import os
import numpy as np
import pandas as pd
import sklearn
from sklearn.preprocessing import MinMaxScaler
from tqdm import tqdm
import datetime
from datetime import datetime

#Plot Modules
import matplotlib.pyplot as plt
import seaborn as sns
from pylab import rcParams
from matplotlib import rc
import matplotlib


#Pytorch Modules 
import torch
import pytorch_lightning as pl
import torch.autograd as autograd
import torch.nn as nn
import torch.optim as optim
from torch.optim import Adam
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
from pytorch_lightning.callbacks import ModelCheckpoint, EarlyStopping
from pytorch_lightning.loggers import TensorBoardLogger

#Tensor Board Modules
from torchsummary import summary
from torch.utils.tensorboard import SummaryWriter

print("PyTorch Version: ",torch.__version__)

# %%
#Plot Settings

# %matplotlib inline
# %config InlineBackend.figure_format='retina'

sns.set(style='whitegrid', palette='muted', font_scale=1.2)

HAPPY_COLORS_PALETTE = ["#01BEFE", "#FFDD00", "#FF7D00", "#FF006D", "#93D30C", "#8F00FF"]

sns.set_palette(sns.color_palette(HAPPY_COLORS_PALETTE))

rcParams['figure.figsize'] = 12, 8

tqdm.pandas()

# %%
#Seeding everything

pl.seed_everything(42)

# %% [markdown]
# ## Helper Functions

# %% [markdown]
# ### Function 1: Converts a time series into sequences of data

# %%
def create_sequences(input_data: pd.DataFrame, target_column, sequence_lenght):
    sequences = []  
    data_size = len(input_data)  
    
    for i in tqdm(range(data_size - sequence_lenght)): #iterating over the data in batches
        sequence = input_data[i:i+sequence_lenght] #
        
        label_position = i + sequence_lenght
        label = input_data.iloc[label_position][target_column]
        
        sequences.append((sequence, label))
        
    return sequences

# %% [markdown]
# ## Loading the dataset

# %%
#For the analysis we will use Alphabet Stock Prices

df = pd.read_csv('/Users/lemon/Desktop/Stock Price Prediciton/GOOG.csv', sep = ',')
df = df[-1189:] #We only use the daily stocks prices from 2018

# %%
df.head()
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 3343  2018-01-02  52.417000  53.347000  52.261501  53.250000  53.250000
# 3344  2018-01-03  53.215500  54.314499  53.160500  54.124001  54.124001
# 3345  2018-01-04  54.400002  54.678501  54.200100  54.320000  54.320000
# 3346  2018-01-05  54.700001  55.212502  54.599998  55.111500  55.111500
# 3347  2018-01-08  55.111500  55.563499  55.081001  55.347000  55.347000
#
#         Volume
# 3343  24752000
# 3344  28604000
# 3345  20092000
# 3346  25582000
# 3347  20952000

# %% [markdown]
# ## Preprocessing

# %%
#Parsing Dates
df['Date'] = pd.to_datetime(df['Date'], format='%Y/%m/%d')

#Creting a new feature (Daily Change) with the 
df['Previous_Day'] = df.shift(1)['Close']
df.iloc[[0],[7]] = 0
df['Daily Change'] = df['Close'] - df['Previous_Day'] 
df.iloc[[0],[8]] = 0

# %%
#creating a new data frame and putting Close as last column
df1 = df.reset_index()[['Date', 'Open', 'High', 'Low', 'Adj Close', 'Volume',
       'Previous_Day', 'Daily Change', 'Close']]

#setting the dates as dataframe indices
df1 = df1.set_index("Date")

df1.head()
# Out:
#                  Open       High        Low  Adj Close    Volume  \
# Date
# 2018-01-02  52.417000  53.347000  52.261501  53.250000  24752000
# 2018-01-03  53.215500  54.314499  53.160500  54.124001  28604000
# 2018-01-04  54.400002  54.678501  54.200100  54.320000  20092000
# 2018-01-05  54.700001  55.212502  54.599998  55.111500  25582000
# 2018-01-08  55.111500  55.563499  55.081001  55.347000  20952000
#
#             Previous_Day  Daily Change      Close
# Date
# 2018-01-02      0.000000      0.000000  53.250000
# 2018-01-03     53.250000      0.874001  54.124001
# 2018-01-04     54.124001      0.195999  54.320000
# 2018-01-05     54.320000      0.791500  55.111500
# 2018-01-08     55.111500      0.235500  55.347000

# %%
#Plotting the Stock Prices and Daily change of the Alphabet Stocks

fig = plt.figure(figsize=(30, 7))
rows = 1
columns = 2


fig.add_subplot(rows, columns, 1)
plt.plot(df1.index, df1["Close"], color = 'red', linewidth=1)
plt.title("Alphabet Closing Stock Price")

fig.add_subplot(rows, columns, 2)
plt.plot(df1.index, df1["Daily Change"], color = 'limegreen', linewidth=1)
plt.title("Alphabet Daily Stock Price Change")


plt.show()

# %%
#Separating the training and test set

train_size = int(len(df1)*0.8) 
test_size = len(df1) - train_size 

train_df, test_df = df1[0:train_size],df1[train_size:len(df1)]

print(f'train dataset shape {train_df.shape}, test dataset shape {test_df.shape}')
# Out:
# train dataset shape (951, 8), test dataset shape (238, 8)

# %%
#Normalizing the data using MinMaxScaler
#The scaler will be parametrized using the training data because we don't want to induce a bias in the model by
#    using test data

scaler = MinMaxScaler(feature_range=(0,1))
scaler = scaler.fit(train_df) 

#creating new train dataframe with scaled values
train_df = pd.DataFrame(scaler.transform(train_df), 
                        index = train_df.index, 
                        columns = train_df.columns)

test_df = pd.DataFrame(scaler.transform(test_df), 
                        index = test_df.index, 
                        columns = test_df.columns)

# %%
train_df.head()
# Out:
#                 Open      High       Low  Adj Close    Volume  Previous_Day  \
# Date
# 2018-01-02  0.038271  0.032801  0.038678   0.045748  0.152008      0.000000
# 2018-01-03  0.046481  0.042812  0.047936   0.054756  0.184874      0.365121
# 2018-01-04  0.058661  0.046578  0.058641   0.056776  0.112249      0.371114
# 2018-01-05  0.061745  0.052104  0.062759   0.064933  0.159090      0.372458
# 2018-01-08  0.065976  0.055736  0.067713   0.067360  0.119586      0.377885
#
#             Daily Change     Close
# Date
# 2018-01-02      0.487121  0.045748
# 2018-01-03      0.550007  0.054756
# 2018-01-04      0.501223  0.056776
# 2018-01-05      0.544071  0.064933
# 2018-01-08      0.504065  0.067360

# %% [markdown]
# ## Converting the sequences into a pytorch tensor

# %%
class GDataset(Dataset):
    
    def __init__(self, sequences):
        self.sequences = sequences
        
    def __len__(self):
        return len(self.sequences)
    
    def __getitem__(self, idx):
        sequence, label = self.sequences[idx]
        
        return dict(
        sequence = torch.Tensor(sequence.to_numpy()),  
        label = torch.tensor(label).float()
        )

# %%
class PriceDataModule(pl.LightningDataModule):
    
    def __init__(self, train_sequences, test_sequences, batch_size = 8):
        super().__init__()
        self.train_sequences = train_sequences
        self.test_sequences = test_sequences
        self.batch_size = batch_size
        
    def setup(self, stage = None):
        self.train_dataset = GDataset(self.train_sequences)
        self.test_dataset = GDataset(self.test_sequences)
        
    def train_dataloader(self):
        return DataLoader(
            self.train_dataset,
            batch_size = self.batch_size,
            shuffle = False,
#            num_workers = 8
        )
    
    def val_dataloader(self):
        return DataLoader(
        self.test_dataset,
            batch_size = 1,
            shuffle = False,
#            num_workers = 8
        )
    
    def test_dataloader(self):
        return DataLoader(
        self.test_dataset,
            batch_size = 1,
            shuffle = False,
#            num_workers = 8
        )

# %% [markdown]
# ## Model and Training Procedure

# %%
#Setting Up an LSTM model
class PredModel(nn.Module):
    def __init__(self, n_features, n_hidden=5, n_layers = 1):
        super().__init__()
        
        self.n_hidden = n_hidden
        
        self.lstm = nn.LSTM(
            input_size = n_features,
            hidden_size = n_hidden,
            batch_first = True,
            num_layers = n_layers,
#            dropout = 0.5
        )
        
        self.regressor = nn.Linear(n_hidden, 1)
        
    def forward(self,x):
        self.lstm.flatten_parameters()
        
        _, (hidden, _) = self.lstm(x)
        out = hidden[-1]
        
        return self.regressor(out)

# %%
#Traing Procedure for the LSTM model

class PricePredictor(pl.LightningModule):
    def __init__(self, n_features: int, learning_rate = 0.001, n_hid = 5, n_lay = 1):
        super().__init__()
        self.model = PredModel(n_features, n_hidden = n_hid, n_layers = n_lay)
        self.criterion = nn.MSELoss()
        self.learning_rate = learning_rate
        
    def forward(self, x, labels = None):
        output = self.model(x)
        loss = 0
        if labels is not None:
            loss = self.criterion(output, labels.unsqueeze(dim=1))
        return loss, output
    
    def training_step(self, batch, batch_idx):
        sequences = batch['sequence']
        labels = batch['label']
        loss, outputs = self(sequences, labels)
        self.log('train_loss', loss, prog_bar = True, logger = True)
        return loss
    
    def validation_step(self, batch, batch_idx):
        sequences = batch['sequence']
        labels = batch['label']
        loss, outputs = self(sequences, labels)
        self.log('val_loss', loss, prog_bar = True, logger = True)
        return loss
    
    def test_step(self, batch, batch_idx):
        sequences = batch['sequence']
        labels = batch['label']
        loss, outputs = self(sequences, labels)
        self.log('test_loss', loss, prog_bar = True, logger = True)
        return loss
    
    def configure_optimizers(self):
        return optim.AdamW(self.parameters(), lr=self.learning_rate)

# %% [markdown]
# ## Training

# %%
# %%capture --no-display

#Grid Search will be implmented to find the best set of hyperparameters

N_EPOCHS = 1000
BATCH_SIZE = 64

#Hyperparameters
hidden_layers = [1,3,5,10]
num_layers = [1,3,5,10]
sequences_lenghts = [5]
learning_rates = [0.001]


for hid in hidden_layers:
    for lay in num_layers:
        for seq in sequences_lenghts:
            
            train_sequences = create_sequences(train_df, 'Close', seq)
            test_sequences = create_sequences(test_df, 'Close', seq)

            data_module = PriceDataModule(train_sequences, test_sequences, batch_size = BATCH_SIZE)
            data_module.setup()

            for l_rate in learning_rates:
                
                checkpoint_callback = ModelCheckpoint(
                    dirpath = f"checkpoint hidden layers = {hid}, num_layers = {lay}, l. rate ={l_rate}, seq. len = {seq} ",
                    filename = 'best_model',
                    save_top_k = 1,
                    verbose = True,
                    monitor = 'val_loss',
                    mode = 'min'
                )
                
                print(f'optimizing for seq_lenght = {seq}, learning rate = {l_rate}')
                model = PricePredictor(n_features = train_df.shape[1], learning_rate = l_rate, n_hid = hid, n_lay = lay)

                logger = TensorBoardLogger('lightning_logs', name = 'Google-price')
                early_stopping_callback = EarlyStopping(monitor = 'val_loss', patience = 50)

                trainer = pl.Trainer(
                    logger = logger,
                    enable_checkpointing = True,
                    callbacks = [checkpoint_callback],
                    max_epochs = N_EPOCHS,
                    accelerator = 'cpu',
                    devices = 1,
                    log_every_n_steps=1000
                )

                trainer.fit(model, data_module) #model training
                checkpoint_callback.best_model_path

# %% [markdown]
# ## Results

# %%
#Loading the training statistics in Tensorboard

# %reload_ext tensorboard
# %tensorboard --logdir ./lightning_logs

# %% [markdown]
# ## Predictions

# %%
#Loading the best model

trained_model = PricePredictor.load_from_checkpoint(
    'best_model',
    n_features = train_df.shape[1]
)

trained_model.freeze()

# %%
#Generating the predictions

test_dataset = GDataset(test_sequences)

predictions = []
labels = []

for item in tqdm(test_dataset):
    sequence = item['sequence']
    label = item['label']
    
    _, output = trained_model(sequence.unsqueeze(dim=0))
    predictions.append(output.item())
    labels.append(label.item())

# %%
#Descaling the results and the test dataset

descaler = MinMaxScaler()
descaler.min_, descaler.scale_ = scaler.min_[-1], scaler.scale_[-1]

def descale(descaler, values):
    values_2d = np.array(values)[:, np.newaxis]
    return descaler.inverse_transform(values_2d).flatten()

predictions_descaled = descale(descaler, predictions)
labels_descaled = descale(descaler, labels)

# %%
#Plotting the predictions and the actual values

fig = plt.figure(figsize=(20, 7))
rows = 1
columns = 1

fig.add_subplot(rows, columns, 1)
plt.plot(df1.index[-len(predictions_descaled):], labels_descaled, color = 'red', linewidth=1 , label = 'Actual Values')
plt.plot(df1.index[-len(predictions_descaled):], predictions_descaled, color = 'Blue', linewidth = 1, label = 'Predictions')
plt.title("Prediction vs Actual")
plt.legend()
plt.show()
